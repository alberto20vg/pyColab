# %% [markdown]
# Esto es un archivo de prueba
#
# ---

# %%
import pandas as pd

dfCovid = pd.read_csv('https://opendata.ecdc.europa.eu/covid19/casedistribution/csv')

#dfCovid.head()
dfCovid.corr()
# Out:
#                                                  cases_weekly  ...  notification_rate_per_100000_population_14-days
# cases_weekly                                         1.000000  ...                                         0.241428
# deaths_weekly                                        0.850176  ...                                         0.215727
# popData2019                                          0.265719  ...                                        -0.048010
# notification_rate_per_100000_population_14-days      0.241428  ...                                         1.000000
#
# [4 rows x 4 columns]
